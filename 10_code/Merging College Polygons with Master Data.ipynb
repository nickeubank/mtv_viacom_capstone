# %%
import geopandas as gpd
import pandas as pd

# %%
master_data=pd.read_csv("SLSV Master Campus Sheet - Master Sheet.csv",header=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/mz/72pm8_k52zg04yv8wtwty5ym0000gn/T/ipykernel_2830/2441649437.py in <module>
# ----> 1 master_data=pd.read_csv("SLSV Master Campus Sheet - Master Sheet.csv",header=1)
#
# ~/opt/anaconda3/envs/geo/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
master_data=master_data.iloc[1:,:]

# %%
master_data

# %%
master_data=master_data.dropna(subset=['School Name'])

# %%
college_data=pd.read_csv("College_Polygon.csv", index_col=False)

# %%
college_data = gpd.read_file("College_Polygon.geojson")

# %%
college_data=college_data.dropna(subset=['name'])

# %%
college_data['centroid']=college_data.centroid

# %%
college_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mz/72pm8_k52zg04yv8wtwty5ym0000gn/T/ipykernel_2830/4009764139.py in <module>
# ----> 1 college_data
#
# NameError: name 'college_data' is not defined

# %%
# initializing punctuations string

 
# Removing punctuations in string
# Using loop + punctuation string
def string_punc(test_str):
    print(test_str)
    
    punc = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''
    try:
        test_str=str(test_str)
        for ele in test_str:
            if ele in punc:
                test_str = test_str.replace(ele, "")

        return test_str.lower()
    except:
        return 'Null'


for i,r in college_data.iterrows():
    college_data.loc[i,'name']=string_punc(college_data.loc[i,'name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mz/72pm8_k52zg04yv8wtwty5ym0000gn/T/ipykernel_2830/2274746847.py in <module>
#      19
#      20
# ---> 21 for i,r in college_data.iterrows():
#      22     college_data.loc[i,'name']=string_punc(college_data.loc[i,'name'])
#
# NameError: name 'college_data' is not defined

# %%
master_data
# Out:
#        State    OPE ID    IPED ID  \
# 1         AK   1061.00  102669.00
# 2         AK  34613.00  434584.00
# 3         AK       NaN        NaN
# 4         AK  11462.00  102553.00
# 5         AK   1063.00  102614.00
# ...      ...       ...        ...
# 3108      WY   3930.00  240666.00
# 3109      WY   3931.00  240657.00
# 3110      WY   3932.00  240727.00
# 3111      WY   3933.00  240693.00
# 3113  Counts       NaN        NaN
#
#                                       School Name Institution Type  \
# 1                       Alaska Pacific University  Private, 4 Year
# 2                               Ilisagvik College   Public, 4 Year
# 3          Prince William Sound Community College              NaN
# 4                 University of Alaska, Anchorage   Public, 4 Year
# 5                 University of Alaska, Fairbanks   Public, 4 Year
# ...                                           ...              ...
# 3108  Northern Wyoming Community College District              NaN
# ...

# %%
for i,r in master_data.iterrows():
    master_data.loc[i,'School Name']=string_punc(master_data.loc[i,'School Name'])
# Out:
# Alaska Pacific University
# Ilisagvik College
# Prince William Sound Community College
# University of Alaska, Anchorage
# University of Alaska, Fairbanks
# University of Alaska, Southeast
# Alabama A & M University
# Alabama State University
# Amridge University
# Athens State University
# Auburn University
# Auburn University, Montgomery
# Bevill State Community College
# Birmingham Southern College
# Bishop State Community College
# Calhoun Community College
# Central Alabama Community College
# Chattahoochee Valley Community College
# Columbia Southern University
# Concordia College Alabama
# Enterprise State Community College
# Faulkner University
# Gadsden State Community College
# George C. Wallace Community College
# Heritage Christian University
# Herzing University - Birmingham
# Huntingdon College
# Jacksonville State University
# Jefferson State Community College
# JF Drake State Technical College
# Judson College
# Lawson State Community College
# ...

# %%
college_data=college_data[~college_data['name'].str.contains('hall|beta|phi|laboratory|center|house|program|theater|apartment', regex=True)]

# %%
college_data
# Out:
#          amenity                                        name  \
# 0     university           university of maine at farmington
# 1     university                 university of new brunswick
# 2     university                        st thomas university
# 3     university      university of new brunswick saint john
# 4     university                            université laval
# ...          ...                                         ...
# 8771     college                        school of educations
# 8772     college                     college of liberal arts
# 8773     college  college of rural and community development
# 8774     college                        school of management
# 8775     college        college of engineering and mines cem
#
#                                                geometry  \
# 0     POLYGON ((-70.14970 44.66690, -70.14992 44.666...
# 1     POLYGON ((-66.64555 45.94583, -66.64530 45.945...
# 2     POLYGON ((-66.64555 45.94583, -66.64583 45.945...
# ...

# %%
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
for i,r in college_data.iterrows():
    college_data.loc[i,'x_centroid']=college_data.loc[i,'centroid'].x
    college_data.loc[i,'y_centroid']=college_data.loc[i,'centroid'].y
# Out:
# /Users/pranavmanjunath/opt/anaconda3/envs/geo/lib/python3.9/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/pranavmanjunath/opt/anaconda3/envs/geo/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
college_data=college_data

# %%
college_data['centroid_geom'] = college_data['x_centroid'].map(str) + ', ' + college_data['y_centroid'].map(str)

# %%
college_data
# Out:
#          amenity                                        name  \
# 0     university           university of maine at farmington
# 1     university                 university of new brunswick
# 2     university                        st thomas university
# 3     university      university of new brunswick saint john
# 4     university                            université laval
# ...          ...                                         ...
# 8771     college                        school of educations
# 8772     college                     college of liberal arts
# 8773     college  college of rural and community development
# 8774     college                        school of management
# 8775     college        college of engineering and mines cem
#
#                                                geometry  \
# 0     POLYGON ((-70.14970 44.66690, -70.14992 44.666...
# 1     POLYGON ((-66.64555 45.94583, -66.64530 45.945...
# 2     POLYGON ((-66.64555 45.94583, -66.64583 45.945...
# ...

# %%
#appending US state polygons and finding out with centroid of college belongs inside state
us_state = gpd.read_file("us-state-boundaries.geojson")

# %%
us_state
# Out:
#        arealand  division     centlon    areawater  objectid  \
# 0     348013711         0  -64.838762   1550244357        35
# 1   -1459974156         3  -89.709771   -703725080        16
# 2   -1896337421         1  -72.666041   1031126051        10
# 3    1870899812         2  -74.658042   -753053640        15
# 4    2141806805         8 -105.547828   1174677436        27
# 5     552436514         5  -80.858324    775849516        28
# 6    1570063024         7  -97.494707   -921131230        29
# 7   -1698712947         3  -86.287267   1536739330        49
# 8    -992712557         8 -109.632986   -427433562        47
# 9    -621920778         5  -76.678966  -1606750401         5
# 10    637075652         8 -106.112659    755396976        13
# 11    158364994         5  -77.016274     18633403        54
# 12   2140782230         8 -111.660548   1027348231        56
# 13    861485430         8 -116.631344   2047350889        40
# ...

# %%
college_data
# Out:
#          amenity                                        name  \
# 0     university           university of maine at farmington
# 1     university                 university of new brunswick
# 2     university                        st thomas university
# 3     university      university of new brunswick saint john
# 4     university                            université laval
# ...          ...                                         ...
# 8771     college                        school of educations
# 8772     college                     college of liberal arts
# 8773     college  college of rural and community development
# 8774     college                        school of management
# 8775     college        college of engineering and mines cem
#
#                                                geometry  \
# 0     POLYGON ((-70.14970 44.66690, -70.14992 44.666...
# 1     POLYGON ((-66.64555 45.94583, -66.64530 45.945...
# 2     POLYGON ((-66.64555 45.94583, -66.64583 45.945...
# ...

# %%
for i, r in college_data.iterrows():
    for i1,r1 in us_state.iterrows():
        try:
            if college_data.loc[i,'centroid'].within(us_state.loc[i1,'geometry']):
    
                college_data.loc[i,'State']=us_state.loc[i1,'name']
                break
        except:
            continue
# Out:
# /Users/pranavmanjunath/opt/anaconda3/envs/geo/lib/python3.9/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/pranavmanjunath/opt/anaconda3/envs/geo/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
college_data
# Out:
#          amenity                                        name  \
# 0     university           university of maine at farmington
# 1     university                 university of new brunswick
# 2     university                        st thomas university
# 3     university      university of new brunswick saint john
# 4     university                            université laval
# ...          ...                                         ...
# 8771     college                        school of educations
# 8772     college                     college of liberal arts
# 8773     college  college of rural and community development
# 8774     college                        school of management
# 8775     college        college of engineering and mines cem
#
#                                                geometry  \
# 0     POLYGON ((-70.14970 44.66690, -70.14992 44.666...
# 1     POLYGON ((-66.64555 45.94583, -66.64530 45.945...
# 2     POLYGON ((-66.64555 45.94583, -66.64583 45.945...
# ...

# %%
college_data=college_data.dropna(subset=['State'])

# %%
college_data.head(20)
# Out:
#        amenity                                   name  \
# 0   university      university of maine at farmington
# 5   university              university of new england
# 21  university                      husson university
# 22  university              university of maine orono
# 24  university       university of maine at fort kent
# 28  university    university of maine at presque isle
# 30  university                          bates college
# 34  university         university of maine at augusta
# 35  university                 maine maritime academy
# 46  university  massachusetts institute of technology
# 48  university                     swarthmore college
# 49  university                      rivier university
# 51  university                      howard university
# 53  university             loyola university maryland
# 54  university                  university of vermont
# 55  university               university of pittsburgh
# ...

# %%
college_data=college_data.drop(columns=['centroid'])

# %%
college_data=pd.DataFrame(college_data)

# %%
_=college_data.to_csv('final_college_polygons.csv')

# %% [markdown]
# --------REVERSE GEOCODING-----------

# %%
locator = Nominatim(user_agent='myGeocoder')
#rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)

locator.reverse("-71.27555,46.78153")

# %%
from functools import partial
reverse = partial(locator.reverse)
print(reverse((-71.27555,46.78153)))
# Out:
# None

# %%
from urllib.request import urlretrieve

# %%
urlretrieve("https://google.com").read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mz/72pm8_k52zg04yv8wtwty5ym0000gn/T/ipykernel_2961/2414678765.py in <module>
# ----> 1 urlretrieve("https://google.com").read()
#
# AttributeError: 'tuple' object has no attribute 'read'

# %%
from urllib.request import urlopen
import json
def getplace(lat, lon):
    url = "https://maps.googleapis.com/maps/api/geocode/json?"
    url += "latlng=%s,%s&sensor=false&key=AIzaSyAqWiye83cMRhMGBq2M5fesfUuO1NT4lbw" % (lat, lon)
    v = urlopen(url).read()
    j = json.loads(v)
    print(j)
    components = j['results'][0]['address_components']
    country = town = None
    for c in components:
        if "country" in c['types']:
            country = c['long_name']
        if "postal_town" in c['types']:
            town = c['long_name']
    return town, country

getplace(51.1, 0.1)
# Out:
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'results': [], 'status': 'REQUEST_DENIED'}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/mz/72pm8_k52zg04yv8wtwty5ym0000gn/T/ipykernel_2961/2980689788.py in <module>
#      16     return town, country
#      17
# ---> 18 getplace(51.1, 0.1)
#
# /var/folders/mz/72pm8_k52zg04yv8wtwty5ym0000gn/T/ipykernel_2961/2980689788.py in getplace(lat, lon)
#       7     j = json.loads(v)
#       8     print(j)
# ----> 9     components = j['results'][0]['address_components']
#      10     country = town = None
#      11     for c in components:
#
# IndexError: list index out of range

# %%
for i,r in college_data.iterrows():
    cent=college_data.loc[i,'centroid_geom']
    college_data.loc[i,'address']=locator.reverse(cent)
# Out:
# /Users/pranavmanjunath/opt/anaconda3/envs/geo/lib/python3.9/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /Users/pranavmanjunath/opt/anaconda3/envs/geo/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# ---------------------------------------------------------------------------
# ...

# %%
college_data['address'].value_counts()
# Out:
# Series([], Name: address, dtype: int64)

# %%
location

# %%
college_data
# Out:
#          amenity                                        name  \
# 0     university           university of maine at farmington
# 1     university                 university of new brunswick
# 2     university                        st thomas university
# 3     university      university of new brunswick saint john
# 4     university                            université laval
# ...          ...                                         ...
# 8771     college                        school of educations
# 8772     college                     college of liberal arts
# 8773     college  college of rural and community development
# 8774     college                        school of management
# 8775     college        college of engineering and mines cem
#
#                                                geometry  \
# 0     POLYGON ((-70.14970 44.66690, -70.14992 44.666...
# 1     POLYGON ((-66.64555 45.94583, -66.64530 45.945...
# 2     POLYGON ((-66.64555 45.94583, -66.64583 45.945...
# ...

# %%
#Removing puncutation from both master and college data

# %%
master_data
# Out:
#        State    OPE ID    IPED ID  \
# 1         AK   1061.00  102669.00
# 2         AK  34613.00  434584.00
# 3         AK       NaN        NaN
# 4         AK  11462.00  102553.00
# 5         AK   1063.00  102614.00
# ...      ...       ...        ...
# 3108      WY   3930.00  240666.00
# 3109      WY   3931.00  240657.00
# 3110      WY   3932.00  240727.00
# 3111      WY   3933.00  240693.00
# 3113  Counts       NaN        NaN
#
#                                       School Name Institution Type  \
# 1                       alaska pacific university  Private, 4 Year
# 2                               ilisagvik college   Public, 4 Year
# 3          prince william sound community college              NaN
# 4                  university of alaska anchorage   Public, 4 Year
# 5                  university of alaska fairbanks   Public, 4 Year
# ...                                           ...              ...
# 3108  northern wyoming community college district              NaN
# ...

# %%
for i,r in college_data.iterrows():
    college_data.loc[i,'name']=string_punc(college_data.loc[i,'name'])
# Out:
# university of maine at farmington
# university of new brunswick
# st thomas university
# university of new brunswick saint john
# université laval
# university of new england
# hut 5
# unbea building
# university of new brunswick
# renaissance college
# university of new brunswick
# beta theta pi
# husson university
# university of maine orono
# saint stephens university
# university of maine at fort kent
# université sainteanne
# university of maine at presque isle
# st thomas university  lower campus
# bates college
# huntsman marine science centre lower campus
# university of maine at augusta
# maine maritime academy
# uqar
# université laval  édifice de la fabrique
# université du québec  téléuniversité
# école nationale dadministration publique
# université laval  édifice du vieuxséminairedequébec
# centre étudiant
# campus dedmundston  université de moncton
# massachusetts institute of technology
# swarthmore college
# rivier university
# howard university
# ...

# %%
college_data[college_data['name']=='northwest college']
# Out:
#       amenity               name                     geometry  \
# 8672  college  northwest college  POINT (-118.25526 34.14889)
#
#                          centroid  x_centroid  y_centroid  \
# 8672  POINT (-118.25526 34.14889) -118.255259   34.148891
#
#                 centroid_geom
# 8672  -118.2552594,34.1488914

# %%
master_data
# Out:
#        State    OPE ID    IPED ID  \
# 1         AK   1061.00  102669.00
# 2         AK  34613.00  434584.00
# 3         AK       NaN        NaN
# 4         AK  11462.00  102553.00
# 5         AK   1063.00  102614.00
# ...      ...       ...        ...
# 3108      WY   3930.00  240666.00
# 3109      WY   3931.00  240657.00
# 3110      WY   3932.00  240727.00
# 3111      WY   3933.00  240693.00
# 3113  Counts       NaN        NaN
#
#                                       School Name Institution Type  \
# 1                       Alaska Pacific University  Private, 4 Year
# 2                               Ilisagvik College   Public, 4 Year
# 3          Prince William Sound Community College              NaN
# 4                 University of Alaska, Anchorage   Public, 4 Year
# 5                 University of Alaska, Fairbanks   Public, 4 Year
# ...                                           ...              ...
# 3108  Northern Wyoming Community College District              NaN
# ...

# %%
final_data=master_data.merge(college_data, left_on='School Name', right_on='name',how='inner')

# %%
final_data
# Out:
#      State    OPE ID    IPED ID                             School Name  \
# 0       AK   1061.00  102669.00               alaska pacific university
# 1       AK   1061.00  102669.00               alaska pacific university
# 2       AK  34613.00  434584.00                       ilisagvik college
# 3       AK       NaN        NaN  prince william sound community college
# 4       AK  11462.00  102553.00          university of alaska anchorage
# ...    ...       ...        ...                                     ...
# 2236    WY   9259.00  240620.00        laramie county community college
# 2237    WY   9259.00  240620.00        laramie county community college
# 2238    WY   3931.00  240657.00                       northwest college
# 2239    WY   3932.00  240727.00                   university of wyoming
# 2240    WY   3933.00  240693.00       western wyoming community college
#
#      Institution Type  # of Nat'l AP Partners  # of Partners  Civic Holiday  \
# ...

# %%
final_data['College Name'].value_counts()

# %%
sum(final_data['name']=='Null')

# %%
sum(final_data['name'].isna())

# %%
final_data
