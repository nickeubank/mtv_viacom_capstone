# %% [markdown]
# ## Initial Look at SafeGraph 2020 Polling Place Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# ### Executive Summary
# Latitude and longitude are included for all 3 types of polling place. Polling hours, start date, and end date are included as columns, though sometimes missing.
#
# 1) Traditional Polling Places
# - All 50 states are covered
# - Little missing data for our most important fields
#
# 2) Early Polling Places
# - Only 11 states are present in this dataset
#
# 3) Dropoff Polling Places
# - 35 states are present in this dataset
# - Seem to be concentrated in the Northeast

# %% [markdown]
# ### Load Data

# %%
polling = pd.read_csv('../Data/2020 Polling Data/polling_pk_master_post.csv')
early = pd.read_csv('../Data/2020 Polling Data/earlyVote_pk_master.csv')
dropoff = pd.read_csv('../Data/2020 Polling Data/dropoff_pk_master.csv')

# %% [markdown]
# ### 1. Traditional Polling Places

# %%
polling.head()
# Out:
#    query_id             placekey            error             pollingHours  \
# 0         0      223@8m4-tbj-bp9              NaN  Tue, Nov 3: 7 am - 7 pm
# 1         1         @8m4-t4v-q4v  Invalid address  Tue, Nov 3: 7 am - 7 pm
# 2         2         @8m4-793-jvz  Invalid address  Tue, Nov 3: 7 am - 7 pm
# 3         3         @bp5-ytd-j35  Invalid address  Tue, Nov 3: 7 am - 7 pm
# 4         4  zzw-222@bp5-chr-8y9              NaN  Tue, Nov 3: 7 am - 7 pm
#
#     latitude   longitude                                            sources  \
# 0  21.305224 -157.857002  [{'name': 'Voting Information Project', 'offic...
# 1  21.329854 -158.081865  [{'name': 'Voting Information Project', 'offic...
# 2  21.090406 -157.017609  [{'name': 'Voting Information Project', 'offic...
# 3  20.826513 -156.921143  [{'name': 'Voting Information Project', 'offic...
# 4  20.900159 -156.491939  [{'name': 'Voting Information Project', 'offic...
#
#                                 address.locationName  \
# 0                                      Honolulu Hale
# 1                                       Kapolei Hale
# 2             Mitchell Pauole Center Conference Room
# 3  Lanai Council District Office Lanai Community ...
# 4              Velma McWayne Santos Community Center
#
#                    address.line1 address.city address.state address.zip  \
# 0          530 South King Street     Honolulu            HI       96813
# 1          1000 Uluʻōhiʻa Street      Kapolei            HI       96707
# 2                90 Ainoa Street   Kaunakakai            HI       96748
# 3  Lanai Council District Office   Lanai City            HI       96763
# 4               395 Waena Street      Wailuku            HI       96793
#
#                                                notes  startDate    endDate  \
# 0  Voter service centers provide accessible in-pe...  11/3/2020  11/3/2020
# 1  Voter service centers provide accessible in-pe...  11/3/2020  11/3/2020
# 2  Voter service centers provide accessible in-pe...  11/3/2020  11/3/2020
# 3  Voter service centers provide accessible in-pe...  11/3/2020  11/3/2020
# 4  Voter service centers provide accessible in-pe...  11/3/2020  11/3/2020
#
#   address.line2 address.line3  id
# 0           NaN           NaN NaN
# 1           NaN           NaN NaN
# 2           NaN           NaN NaN
# 3    8th Street           NaN NaN
# 4           NaN           NaN NaN

# %% [markdown]
# #### 1a) Which states are covered?

# %%
#Which states are covered?
print(len(polling['address.state'].unique()))
polling['address.state'].unique()
# Out:
# 55
# array(['HI', 'IL', 'MO', 'MO ', 'KS', 'WI', 'NV', 'MN', 'SD', 'IA', 'WA',
#        'AK', 'AL', 'MS', 'TN', 'GA', 'KY', 'OH', 'IN', 'MI', 'TX',
#        'Texas', 'CO', 'WY', 'ND', 'MT ', 'PA', 'FL', 'NH', 'AR', 'NY',
#        'NC', 'Arkansas', nan, 'CA', 'CT', 'AZ', 'DC', 'DE', 'ID', 'UT',
#        'VA', 'VT', 'WV', 'RI', 'MA', 'ME', 'NJ', 'SC', 'NM', 'MD', 'LA',
#        'Louisiana', 'OK', 'NE'], dtype=object)

# %% [markdown]
# We have all 50 states represented here with 5 extra values. "MO", "Arkansas","Lousiana", and "Texas" are duplicates. The fifth value is "nan".

# %% [markdown]
# #### 1b) What % of each column is missing?

# %%
#What % of each column is missing?
polling.isna().sum()*100/len(polling.query_id)
# Out:
# query_id                 0.000000
# placekey                 0.011757
# error                   74.621250
# pollingHours             0.115892
# latitude                 1.545232
# longitude                1.545232
# sources                  0.000000
# address.locationName     0.003359
# address.line1            0.003359
# address.city             0.010078
# address.state            0.010078
# address.zip              0.671840
# notes                   78.454097
# startDate               47.001915
# endDate                 47.001915
# address.line2           97.368067
# address.line3           99.855554
# id                      97.144681
# dtype: float64

# %% [markdown]
# We see small percentages of missing data for our most important columns. Latitude and Longitude have about 1.5% missing values. Polling hours also has < 1% missing data which could benefit our analysis. Address location name, city, state, and zip code also have < 1% missing values.

# %% [markdown]
# #### 1c) What states have less polling place representation?

# %%
state_polling = polling.groupby('address.state').count()

# %%
#Plot count of polling places
figure(figsize=(8, 10))
plt.barh(state_polling.index,state_polling.latitude)
plt.xlabel('Count of Polling Places')
plt.ylabel('State')
# Out:
# Text(0, 0.5, 'State')

# %%
#The states with < 200 polling places
state_polling[state_polling.latitude < 200]
# Out:
#                query_id  placekey  error  pollingHours  latitude  longitude  \
# address.state
# AK                  172       172     58           172       172        172
# Arkansas              1         1      0             1         1          1
# DC                   94        94      0            94        94         94
# DE                  180       180     22           180       180        180
# HI                    8         8      3             8         8          8
# Louisiana             1         1      1             1         1          1
# MO                   11        11      8            11         9          9
# MT                   42        42     23            41        40         40
# ND                  105       105     39           105       105        105
# NV                  192       192     36           192       192        192
# Texas                 1         1      1             1         1          1
# UT                  112       112     32           112       109        109
# WA                   56        56      8             0        56         56
# WY                  163       163     67           163       163        163
#
#                sources  address.locationName  address.line1  address.city  \
# address.state
# AK                 172                   172            172           172
# Arkansas             1                     1              1             1
# DC                  94                    94             94            94
# DE                 180                   180            180           180
# HI                   8                     8              8             8
# Louisiana            1                     1              1             1
# MO                  11                    11             11            11
# MT                  42                    42             42            42
# ND                 105                   105            105           105
# NV                 192                   192            192           192
# Texas                1                     1              1             1
# UT                 112                   110            112           112
# WA                  56                    56             56            56
# WY                 163                   163            163           163
#
#                address.zip  notes  startDate  endDate  address.line2  \
# address.state
# AK                     156      0          0        0              7
# Arkansas                 1      0          1        1              0
# DC                      94      0         94       94              0
# DE                     180      0          0        0              0
# HI                       8      8          8        8              1
# Louisiana                1      0          1        1              0
# MO                      11      0         11       11              0
# MT                      42      2         42       42              2
# ND                     105      0        105      105              1
# NV                     192      0        192      192              5
# Texas                    1      0          1        1              0
# UT                     109      0          0        0              2
# WA                      56     37          0        0              2
# WY                     163      0          0        0              3
#
#                address.line3  id
# address.state
# AK                         0   0
# Arkansas                   0   0
# DC                         0   0
# DE                         0   0
# HI                         0   0
# Louisiana                  0   0
# MO                         0   0
# MT                         0   0
# ND                         1   0
# NV                         1   0
# Texas                      0   0
# UT                         0   0
# WA                         0   0
# WY                         0   0

# %% [markdown]
# #### 1d) Let's look at coverage on a map

# %%
import geopandas

geo_df = geopandas.GeoDataFrame(
    polling, geometry=geopandas.points_from_xy(polling.longitude, polling.latitude))

# %%
geo_df.plot(marker='o', color='blue', markersize=2)

# %% [markdown]
# ### 2. Early Voting Polling Places

# %%
early.head()
# Out:
#    query_id             placekey            error  \
# 0         0      223@8m4-tbj-bp9              NaN
# 1         1         @8m4-t4v-q4v  Invalid address
# 2         2         @8m4-793-jvz  Invalid address
# 3         3         @bp5-ytd-j35  Invalid address
# 4         4  zzw-222@bp5-chr-8y9              NaN
#
#                                         pollingHours   latitude   longitude  \
# 0  Mon, Oct 26: 8:00 am - 4:30 pm\nTue, Oct 27: 8...  21.305224 -157.857002
# 1  Mon, Oct 26: 8:00 am - 4:30 pm\nTue, Oct 27: 8...  21.329854 -158.081865
# 2  Mon, Oct 26: 8:00 am - 4:30 pm\nTue, Oct 27: 8...  21.090406 -157.017609
# 3  Mon, Oct 26: 8:00 am - 4:30 pm\nTue, Oct 27: 8...  20.826513 -156.921143
# 4  Mon, Oct 26: 8:00 am - 4:30 pm\nTue, Oct 27: 8...  20.900159 -156.491939
#
#     startDate    endDate                                            sources  \
# 0  10/20/2020  11/2/2020  [{'name': 'Voting Information Project', 'offic...
# 1  10/20/2020  11/2/2020  [{'name': 'Voting Information Project', 'offic...
# 2  10/20/2020  11/2/2020  [{'name': 'Voting Information Project', 'offic...
# 3  10/20/2020  11/2/2020  [{'name': 'Voting Information Project', 'offic...
# 4  10/20/2020  11/2/2020  [{'name': 'Voting Information Project', 'offic...
#
#                                 address.locationName  \
# 0                                      Honolulu Hale
# 1                                       Kapolei Hale
# 2             Mitchell Pauole Center Conference Room
# 3  Lanai Council District Office Lanai Community ...
# 4              Velma McWayne Santos Community Center
#
#                    address.line1 address.city address.state  address.zip  \
# 0          530 South King Street     Honolulu            HI        96813
# 1          1000 Uluʻōhiʻa Street      Kapolei            HI        96707
# 2                90 Ainoa Street   Kaunakakai            HI        96748
# 3  Lanai Council District Office   Lanai City            HI        96763
# 4               395 Waena Street      Wailuku            HI        96793
#
#                                                notes address.line2 name  \
# 0  Voter service centers provide accessible in-pe...           NaN  NaN
# 1  Voter service centers provide accessible in-pe...           NaN  NaN
# 2  Voter service centers provide accessible in-pe...           NaN  NaN
# 3  Voter service centers provide accessible in-pe...    8th Street  NaN
# 4  Voter service centers provide accessible in-pe...           NaN  NaN
#
#    voterServices
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %% [markdown]
# #### 2a) Which states are covered?

# %%
print(len(early['address.state'].unique()))
early['address.state'].unique()
# Out:
# 11
# array(['HI', 'IL', 'KY', 'IN', 'MI', 'TX', 'CO', 'ND', 'MN', 'AZ', 'NM'],
#       dtype=object)

# %% [markdown]
# We only have 11 states represented in our early voting data and no duplicates.

# %% [markdown]
# #### 2b) What % of each column is missing?

# %%
#What % of each column is missing?
early.isna().sum()*100/len(early.query_id)
# Out:
# query_id                  0.000000
# placekey                  0.000000
# error                    82.721893
# pollingHours             36.804734
# latitude                  0.236686
# longitude                 0.236686
# startDate                38.106509
# endDate                  38.106509
# sources                   0.000000
# address.locationName      0.000000
# address.line1             0.000000
# address.city              0.000000
# address.state             0.000000
# address.zip               0.000000
# notes                    88.047337
# address.line2            91.479290
# name                     98.698225
# voterServices           100.000000
# dtype: float64

# %% [markdown]
# For early voting sites, less than 1% of our sites are missing latitude and longitude. We also have no missing values in the address location name, city, state, and zip. Name is primarily missing. Start date and End date may be unreliable with around 38% missing.

# %% [markdown]
# #### 2c) What states have less early voting representation?

# %%
state_early = early.groupby('address.state').count()

# %%
#Plot count of polling places
figure(figsize=(8, 10))
plt.barh(state_early.index,state_early.latitude)
plt.xlabel('Count of Polling Places')
plt.ylabel('State')
# Out:
# Text(0, 0.5, 'State')

# %%
#The states with < 50 early voting places
state_early[state_early.latitude < 50]
# Out:
#                query_id  placekey  error  pollingHours  latitude  longitude  \
# address.state
# CO                    1         1      0             1         1          1
# HI                    8         8      3             8         8          8
# KY                   17        17      2            17        17         17
# MN                    1         1      0             1         1          1
# ND                   11        11      0             0        11         11
# TX                   43        43     19             4        43         43
#
#                startDate  endDate  sources  address.locationName  \
# address.state
# CO                     1        1        1                     1
# HI                     8        8        8                     8
# KY                    17       17       17                    17
# MN                     0        0        1                     1
# ND                     0        0       11                    11
# TX                     4        4       43                    43
#
#                address.line1  address.city  address.zip  notes  address.line2  \
# address.state
# CO                         1             1            1      0              0
# HI                         8             8            8      8              1
# KY                        17            17           17      2              2
# MN                         1             1            1      0              0
# ND                        11            11           11      0              0
# TX                        43            43           43      0              0
#
#                name  voterServices
# address.state
# CO                0              0
# HI                0              0
# KY                0              0
# MN                0              0
# ND                0              0
# TX                0              0

# %% [markdown]
# #### 2d) Let's look at coverage on a map

# %%
geo_df = geopandas.GeoDataFrame(
    early, geometry=geopandas.points_from_xy(early.longitude, early.latitude))

# %%
geo_df.plot(marker='o', color='blue', markersize=2)

# %% [markdown]
# ### 3) Dropoff Voting Polling Places

# %%
dropoff.head()
# Out:
#    query_id            error             placekey pollingHours   latitude  \
# 0         0  Invalid address         @8m3-vqr-6ff          NaN  21.385785
# 1         1              NaN      223@8m4-t78-yvz          NaN  21.387248
# 2         2              NaN  zzw-222@8m4-tb2-54v          NaN  21.344129
# 3         3  Invalid address         @8m3-vs7-j9z          NaN  21.468407
# 4         4              NaN  zzz-222@8m4-6tp-r8v          NaN  21.409124
#
#     longitude startDate endDate  \
# 0 -157.954228       NaN     NaN
# 1 -157.999190       NaN     NaN
# 2 -157.869922       NaN     NaN
# 3 -158.003795       NaN     NaN
# 4 -157.808878       NaN     NaN
#
#                                              sources  \
# 0  [{'name': 'Voting Information Project', 'offic...
# 1  [{'name': 'Voting Information Project', 'offic...
# 2  [{'name': 'Voting Information Project', 'offic...
# 3  [{'name': 'Voting Information Project', 'offic...
# 4  [{'name': 'Voting Information Project', 'offic...
#
#                      address.locationName              address.line1  \
# 0                  Neal S. Blaisdell Park  98-319 Kamehameha Highway
# 1  Bill Balfour Jr. Waipahu District Park        94-230 Paiwa Street
# 2             Kalihi Valley District Park    1911 Kamehameha IV Road
# 3                  Mililani Park and Ride      95-1101 Ukuwai Street
# 4                   Kaneohe District Park       45-660 Keaahala Road
#
#   address.city address.state address.zip  \
# 0         Aiea            HI       96701
# 1      Waipahu            HI       96797
# 2     Honolulu            HI       96819
# 3     Mililani            HI       96789
# 4      Kaneohe            HI       96744
#
#                                                notes address.line2  \
# 0  Open daily in accordance with park hours from ...           NaN
# 1  Open daily in accordance with park hours from ...           NaN
# 2  Open daily in accordance with park hours from ...           NaN
# 3  Open daily in accordance with park hours from ...           NaN
# 4  Open daily in accordance with park hours from ...           NaN
#
#   address.line3  name voterServices
# 0           NaN   NaN           NaN
# 1           NaN   NaN           NaN
# 2           NaN   NaN           NaN
# 3           NaN   NaN           NaN
# 4           NaN   NaN           NaN

# %% [markdown]
# #### 3a) Which states are covered?

# %%
print(len(dropoff['address.state'].unique()))
dropoff['address.state'].unique()
# Out:
# 35
# array(['HI', 'IL', 'KS', 'NV', 'MN', 'SD', 'WA', 'AK', 'GA', 'OH', 'KY',
#        'MI', 'CO', 'WY', 'ND', 'MT', 'PA', 'FL', 'CT', 'AZ', 'DC', 'DE',
#        'ID', 'UT', 'VA', 'VT', 'RI', 'MA', 'ME', 'NJ', 'NM', 'MD', 'NY',
#        'OR', 'CA'], dtype=object)

# %% [markdown]
# We see that dropoff voting locations are available for 35 states.

# %% [markdown]
# #### 3b) What % of each column is missing?

# %%
#What % of each column is missing?
dropoff.isna().sum()*100/len(dropoff.query_id)
# Out:
# query_id                  0.000000
# error                    83.557789
# placekey                  0.000000
# pollingHours             12.361809
# latitude                  0.683417
# longitude                 0.683417
# startDate                13.520938
# endDate                  13.520938
# sources                   0.000000
# address.locationName      0.000000
# address.line1             0.000000
# address.city              0.000000
# address.state             0.000000
# address.zip               0.469012
# notes                    58.331658
# address.line2            96.730318
# address.line3            99.973199
# name                    100.000000
# voterServices            77.393635
# dtype: float64

# %% [markdown]
# Latitude and longitude are again only missing for < 1% of dropoff voting locations. Start date and end date are slightly less reliable and missing for ~13% of the dropoff voting locations. The address locations name, city, state, and zip code are present for all droppoff voting locations.

# %% [markdown]
# #### 3c) What states have less early voting representation?

# %%
state_dropoff = dropoff.groupby('address.state').count()

# %%
#Plot count of polling places
figure(figsize=(8, 10))
plt.barh(state_dropoff.index,state_dropoff.latitude)
plt.xlabel('Count of Polling Places')
plt.ylabel('State')
# Out:
# Text(0, 0.5, 'State')

# %%
#The states with < 50 early voting places
state_dropoff[state_dropoff.latitude < 100]
# Out:
#                query_id  error  placekey  pollingHours  latitude  longitude  \
# address.state
# AK                   11      0        11            11        11         11
# DC                   55      1        55            55        55         55
# DE                    7      0         7             7         7          7
# FL                   98      3        98            96        97         97
# GA                   63     10        63            63        62         62
# HI                   47     17        47            37        47         47
# ID                   37      1        37            37        37         37
# MN                   77      1        77            77        77         77
# ND                    8      4         8             8         7          7
# OH                   88      1        88            88        88         88
# RI                   41      0        41            41        41         41
# SD                   42      8        42            42        42         42
# WY                   16      1        16            16        16         16
#
#                startDate  endDate  sources  address.locationName  \
# address.state
# AK                    11       11       11                    11
# DC                    55       55       55                    55
# DE                     7        7        7                     7
# FL                    98       98       98                    98
# GA                    63       63       63                    63
# HI                    37       37       47                    47
# ID                    37       37       37                    37
# MN                    77       77       77                    77
# ND                     8        8        8                     8
# OH                    88       88       88                    88
# RI                    41       41       41                    41
# SD                    42       42       42                    42
# WY                    16       16       16                    16
#
#                address.line1  address.city  address.zip  notes  address.line2  \
# address.state
# AK                        11            11           11      1              0
# DC                        55            55           55      4              0
# DE                         7             7            7      6              2
# FL                        98            98           98     88             23
# GA                        63            63           63      0              2
# HI                        47            47           47     47              1
# ID                        37            37           37     23              5
# MN                        77            77           77     50              6
# ND                         8             8            8      7              0
# OH                        88            88           88     53              4
# RI                        41            41           41     41              0
# SD                        42            42           42     27              1
# WY                        16            16           16      6              1
#
#                address.line3  name  voterServices
# address.state
# AK                         0     0              0
# DC                         0     0              0
# DE                         0     0              0
# FL                         0     0              0
# GA                         0     0              0
# HI                         0     0              0
# ID                         0     0              0
# MN                         0     0              0
# ND                         0     0              0
# OH                         0     0              0
# RI                         0     0              0
# SD                         0     0              0
# WY                         0     0              0

# %% [markdown]
# #### 3d) Let's look at coverage on a map

# %%
geo_df.plot(marker='o', color='blue', markersize=2)
